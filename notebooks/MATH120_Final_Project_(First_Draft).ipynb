# %% [markdown]
# ## Final Project Notebook (First Draft)
#
# Name: Adrian Lopez

# %%
import os
import sys

# Check if running in Google Colab
try:
    import google.colab
    IN_COLAB = True
    print("Running in Google Colab")

    # Clone repository if in Colab
    if not os.path.exists('/content/MATH120_Final_Project/'):
        # !git clone https://github.com/Adrian1840/MATH120_Final_Project

    # Change to project directory
    os.chdir('/content/MATH120_Final_Project')

except ImportError:
    IN_COLAB = False
    print("Running locally")

# Add src directory to Python path
if 'src' not in sys.path:
    sys.path.append('src')

print(f"Current working directory: {os.getcwd()}")
# Out:
# Running in Google Colab
# Current working directory: /content/MATH120_Final_Project

# %%
import numpy as np
import pandas as pd
# import plotting packages
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import zipfile

# %% [markdown]
# ## Loading the data & Summary Statistics

# %%
path = "/content/MATH120_Final_Project/data/"

# %%
#overall county-lvl mobility metrics
county = pd.read_csv(path + "11_mobility-metrics_county_longitudinal_0.csv", encoding='latin-1',
    low_memory=False) #used this encoding and false low_memory to fix errors with mixed data types
county.head() #see head of the data
# Out:
#    year  state  county state_name     county_name  population  pctl_income_20  \
# 0  2014      1       1    Alabama  Autauga County       55395     20783.63925
# 1  2014      1       3    Alabama  Baldwin County      200111     19160.07500
# 2  2014      1       5    Alabama  Barbour County       26887     14117.95000
# 3  2014      1       7    Alabama     Bibb County       22506     10951.49550
# 4  2014      1       9    Alabama   Blount County       57719     17143.22500
#
#    pctl_income_20_lb  pctl_income_20_ub pctl_income_20_quality  ...  \
# 0         17647.4375         25210.6250                   Weak  ...
# 1         15832.2725         23193.7750                 Strong  ...
# 2         11596.8875         16538.1700                   Weak  ...
# 3          8974.9825         12907.8400                   Weak  ...
# 4         14924.6900         20672.7125               Marginal  ...
#
#    share_hs_degree_ub  share_hs_degree_quality  share_digital_access  \
# ...

# %%
#racial composition of neighborhoods within a county file
neighbor = pd.read_csv(path + "13_mobility-metrics_county_race-share_longitudinal.csv", encoding='latin-1',
    low_memory=False)
neighbor.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-613237214.py in <cell line: 0>()
#       1 #racial composition of neighborhoods within a county file
# ----> 2 neighbor = pd.read_csv(path + "13_mobility-metrics_county_race-share_longitudinal.csv", encoding='latin-1',
#       3     low_memory=False)
#       4 neighbor.head()
#
# ...

# %%
#summary stats for county-lvl data
county.describe()
# Out:
#                year         state        county    population  pctl_income_20  \
# count  31426.000000  31426.000000  31426.000000  3.142600e+04    25101.000000
# mean    2018.500636     30.275123    103.622065  1.042473e+05    23773.039191
# std        2.872460     15.145037    107.655026  3.319030e+05     7462.105983
# min     2014.000000      1.000000      1.000000  4.300000e+01     8967.533200
# 25%     2016.000000     18.000000     35.000000  1.089300e+04    18843.604200
# 50%     2019.000000     29.000000     79.000000  2.578400e+04    22722.379800
# 75%     2021.000000     45.000000    133.000000  6.816075e+04    27252.309300
# max     2023.000000     56.000000    840.000000  1.017029e+07    84739.884300
#
#        pctl_income_20_lb  pctl_income_20_ub  pctl_income_50  \
# count       25101.000000       25101.000000    25101.000000
# mean        20466.345472       27571.424703    55382.911638
# std          6779.244311        8252.732103    15283.348595
# ...

# %% [markdown]
# ## Research Question 1
# * How have states of the U.S. with the top 5 average affordable housing supply changed from 2014–2023?

# %%
#Avg Share of affordable/available housing units per 100 households w/ very low incomes (50 Area Median Income (AMI)) by state and year
housing_st_yr = county.groupby(["state_name","year"], as_index=False).agg(avg_afford= ("share_affordable_available_50_ami","mean")) #adds pop col with mean of pop
housing_st_yr
# Out:
#     state_name  year  avg_afford
# 0      Alabama  2014    0.895396
# 1      Alabama  2015    0.922718
# 2      Alabama  2016    0.867261
# 3      Alabama  2017    0.974213
# 4      Alabama  2018    0.956483
# ..         ...   ...         ...
# 506    Wyoming  2019    1.106226
# 507    Wyoming  2020         NaN
# 508    Wyoming  2021    0.883896
# 509    Wyoming  2022    0.894997
# 510    Wyoming  2023    0.877508
#
# [511 rows x 3 columns]

# %%
#Gets a vector (.index) of the top 5 states with the lowest average affordability supply
top_5_hous = housing_st_yr.groupby("state_name").mean().sort_values(by="avg_afford",ascending=False).head(5).index

#Gets subset of the avg_st_yr dataframe but only selects the states in the top_5
avg_top = housing_st_yr[housing_st_yr["state_name"].isin(top_5_hous)]

#Plotting Avg affordable/available housing units per 100 households w/ extremely low incomes over years
fig = px.line(
    avg_top,
    x="year",
    y="avg_afford",
    color="state_name",
    markers=True,
    title="Top 5 States in Average Affordable/Available Housing Units per 100 Households Across 2014-2023"
)

fig.update_layout(
    xaxis_title="Year",
    yaxis_title="Avg Units per 100 Households",
    legend_title_text="State"
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# * This graph looks at the 5 states in the United States that have the highest average share of affordable and available housing units per 100 households with very low incomes. These households of very low income are specifically below 50% of the Area Median Income (AMI).
# * As you can see from the above graph that North Dakota had the highest peak in average share of affordable and available housing units per 100 households during the year of 2017. However, this average declines by year 2023 more near the averages of the other four states.

# %% [markdown]
# ## Research Question 2
# * Do these 5 states with more shortages of affordable housing also have higher poverty exposure over time?

# %%
#Avg poverty share (pct) of ppl experiencing poverty who live in high-poverty neighborhoods
poverty_st_yr = county.groupby(["state_name","year"], as_index=False).agg(avg_poverty= ("share_poverty_exposure","mean")) #adds pop col with mean of pop
poverty_st_yr
# Out:
#     state_name  year  avg_poverty
# 0      Alabama  2014     0.104894
# 1      Alabama  2015          NaN
# 2      Alabama  2016     0.114533
# 3      Alabama  2017          NaN
# 4      Alabama  2018     0.093351
# ..         ...   ...          ...
# 506    Wyoming  2019          NaN
# 507    Wyoming  2020          NaN
# 508    Wyoming  2021     0.007398
# 509    Wyoming  2022          NaN
# 510    Wyoming  2023     0.001655
#
# [511 rows x 3 columns]

# %%
#Using top 5 states from prev graph, get subset of poverty exposure d.f.
avg_top2 = poverty_st_yr[poverty_st_yr["state_name"].isin(top_5_hous)].sort_values(["state_name", "year"])

#Plotting Avg poverty exposure for top 5 affordability states
fig = px.line(
    avg_top2,
    x="year",
    y="avg_poverty",
    color="state_name",
    markers=True,
    title="Avg (%) Poverty Exposure by State Over Time for Top 5 States"
)

fig.update_layout(
    xaxis_title="Year",
    yaxis_title="Avg (%) Poverty Exposure",
    legend_title_text="State"
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Using the same states, this is how the average poverty exposure lines up 2014-2023.
#
# FIXME: For some reason, lines are not connecting between dots

# %% [markdown]
# ## Research Question 3
#
# Is there an association between states with more affordable housing shortages and higher poverty exposure?

# %%
#Merging avg affordability share AND avg poverty share
state_combo = pd.merge(housing_st_yr, poverty_st_yr, on=["state_name","year"], how="inner")

state_combo.head()
# Out:
#   state_name  year  avg_afford  avg_poverty
# 0    Alabama  2014    0.895396     0.104894
# 1    Alabama  2015    0.922718          NaN
# 2    Alabama  2016    0.867261     0.114533
# 3    Alabama  2017    0.974213          NaN
# 4    Alabama  2018    0.956483     0.093351

# %%
#Looking at highest year that the data has
latest_year = state_combo["year"].max()

#Subset of the data using latest yr
scat = state_combo[state_combo["year"] == latest_year]

fig = px.scatter(
    scat,
    x="avg_afford",
    y="avg_poverty",
    hover_name="state_name",
    trendline="ols",
    title=f"Housing Availability (AMI 30) vs. Poverty Exposure ({latest_year})",
)

fig.update_layout(
    xaxis_title="Share of People in Poverty",
    yaxis_title="Units per 100 Households",
    legend_title_text="State"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Looking at the regression line, we can see a negative association. May create a model.
